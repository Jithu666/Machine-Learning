# %% [markdown]
# Polynomial Regression

# %% [markdown]
# Importing the Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Load the Dataset

# %%
df = pd.read_csv("D:/AIML/Machine Learning/Part 2 - Regression/Section 6 - Polynomial Regression/Python/Position_Salaries.csv")
X = df.iloc[:, 1:-1].values
y = df.iloc[:, -1].values

# %%
print(X)
# Out:
#             Position  Level
# 0   Business Analyst      1
# 1  Junior Consultant      2
# 2  Senior Consultant      3
# 3            Manager      4
# 4    Country Manager      5
# 5     Region Manager      6
# 6            Partner      7
# 7     Senior Partner      8
# 8            C-level      9
# 9                CEO     10

# %%
print(y)
# Out:
# [  45000   50000   60000   80000  110000  150000  200000  300000  500000
#  1000000]

# %% [markdown]
# Training the Linear Regression Model on the Whole Dataset

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# Visualizing the Linear Regression Results

# %%
plt.scatter(X, y, color='red')
plt.plot(X, regressor.predict(X), color = 'blue')
plt.title('Linear Regression')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# Visualizing the polynomial regression results

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, lin_reg_2.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title("Polynomial Regression")
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
# Out:
# C:\Users\Githendra Gowda\AppData\Local\Temp\ipykernel_13812\4229527944.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)

# %% [markdown]
# Predicting a new Result with Linear Regression

# %%
regressor.predict([[6]])
# Out:
# array([289939.39393939])

# %% [markdown]
# predicting a new result with polynomial regression

# %%
lin_reg_2.predict(poly_reg.fit_transform([[6]]))
# Out:
# array([143275.05827508])
